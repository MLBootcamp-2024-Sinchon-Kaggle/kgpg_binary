# %% [markdown]
# ------------------------------------------------ 데이터 로딩 ------------------------------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 데이터 로드
train = pd.read_csv('/Users/jaesolshin/내 드라이브/2024-2/Google ML Bootcamp2024/data/playground1/train.csv')

# %%
# 전체 데이터의 인덱스 생성
indices = np.arange(train.shape[0])

# 99:1 비율로 train, valid 분할
train_id, valid_id = train_test_split(indices, test_size=0.01, random_state=42)

# train에서 10000개, valid에서 1000개 샘플링
train_sample_id = np.random.choice(train_id, 10000, replace=False)
valid_sample_id = np.random.choice(valid_id, 1000, replace=False)

# train_x, train_y, valid_x, valid_y 생성
train_x = train.iloc[train_sample_id, :-1]
train_y = train.iloc[train_sample_id, -1]
valid_x = train.iloc[valid_sample_id, :-1]
valid_y = train.iloc[valid_sample_id, -1]

print("Train sample X shape:", train_x.shape)
print("Train sample Y shape:", train_y.shape)
print("Valid sample X shape:", valid_x.shape)
print("Valid sample Y shape:", valid_y.shape)
# Out:
# Train sample X shape: (10000, 11)
# Train sample Y shape: (10000,)
# Valid sample X shape: (1000, 11)
# Valid sample Y shape: (1000,)

# %% [markdown]
# ------------------------------------------------ 여기서부터 데이터 확인 및 전처리 ------------------------------------------------

# %%
train_x.head()
train_x.describe(include='all')
# Out:
#                   id Gender           Age  Driving_License   Region_Code  \
# count   1.000000e+04  10000  10000.000000     10000.000000  10000.000000
# unique           NaN      2           NaN              NaN           NaN
# top              NaN   Male           NaN              NaN           NaN
# freq             NaN   5460           NaN              NaN           NaN
# mean    5.791041e+06    NaN     38.309100         0.998500     26.410600
# std     3.306493e+06    NaN     15.012065         0.038703     12.992863
# min     4.240000e+02    NaN     20.000000         0.000000      0.000000
# 25%     2.943422e+06    NaN     24.000000         1.000000     15.000000
# 50%     5.805411e+06    NaN     36.000000         1.000000     28.000000
# 75%     8.654304e+06    NaN     49.000000         1.000000     35.000000
# max     1.150232e+07    NaN     80.000000         1.000000     52.000000
#
#         Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# count         10000.000000       10000          10000    10000.000000
# unique                 NaN           3              2             NaN
# top                    NaN    1-2 Year            Yes             NaN
# freq                   NaN        5170           5062             NaN
# mean              0.463100         NaN            NaN    30390.939100
# std               0.498661         NaN            NaN    16356.570387
# min               0.000000         NaN            NaN     2630.000000
# 25%               0.000000         NaN            NaN    25176.000000
# 50%               0.000000         NaN            NaN    31715.000000
# 75%               1.000000         NaN            NaN    39366.000000
# max               1.000000         NaN            NaN   308615.000000
#
#         Policy_Sales_Channel       Vintage
# count           10000.000000  10000.000000
# unique                   NaN           NaN
# top                      NaN           NaN
# freq                     NaN           NaN
# mean              113.287900    163.479400
# std                53.556322     79.917191
# min                 1.000000     10.000000
# 25%                43.500000     98.000000
# 50%               151.000000    166.000000
# 75%               152.000000    232.000000
# max               163.000000    299.000000

# %%
train_x['Driving_License'].value_counts() #면허 미소지자도 드물게 존재
# Out:
# Driving_License
# 1    9985
# 0      15
# Name: count, dtype: int64

# %%
train_y.value_counts()
# Out:
# Response
# 0    8763
# 1    1237
# Name: count, dtype: int64

# %%
# 범주형 변수들만 따로 확인
train_x.iloc[:10,[1,3,4,5,6,7,9]]
# Out:
#          Gender  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 2812995    Male                1         30.0                   1    1-2 Year
# 9653826    Male                1          8.0                   1    < 1 Year
# 3756146  Female                1         35.0                   0    < 1 Year
# 7295846  Female                1         50.0                   1    < 1 Year
# 8780476    Male                1         28.0                   0    1-2 Year
# 990191   Female                1         28.0                   0    1-2 Year
# 1022727  Female                1          8.0                   0    1-2 Year
# 1091953    Male                1         15.0                   1    < 1 Year
# 9341193    Male                1         28.0                   1    1-2 Year
# 8205635  Female                1          8.0                   0    1-2 Year
#
#         Vehicle_Damage  Policy_Sales_Channel
# 2812995             No                 140.0
# 9653826             No                 152.0
# 3756146            Yes                 160.0
# 7295846             No                 152.0
# 8780476            Yes                  26.0
# 990191             Yes                  26.0
# 1022727            Yes                   7.0
# 1091953             No                 152.0
# 9341193             No                 125.0
# 8205635            Yes                 154.0

# %%
# 범주형 변수를 팩터로 변환 (카테고리형)
train_x.iloc[:,[1,3,4,5,6,7,9]].apply(lambda x: x.astype('category'))
valid_x.iloc[:,[1,3,4,5,6,7,9]].apply(lambda x: x.astype('category'))
# Out:
#          Gender Driving_License Region_Code Previously_Insured Vehicle_Age  \
# 2187507    Male               1         8.0                  0    < 1 Year
# 7032086    Male               1        28.0                  1    1-2 Year
# 4603569    Male               1        14.0                  0    1-2 Year
# 6261642    Male               1        28.0                  0    1-2 Year
# 5480040    Male               1        38.0                  1    1-2 Year
# ...         ...             ...         ...                ...         ...
# 2176172    Male               1        37.0                  0    < 1 Year
# 2451558    Male               1         6.0                  0    1-2 Year
# 6576214  Female               1        36.0                  1    < 1 Year
# 2515429  Female               1        35.0                  1    < 1 Year
# 1071206    Male               1        15.0                  1    < 1 Year
#
#         Vehicle_Damage Policy_Sales_Channel
# 2187507             No                152.0
# 7032086            Yes                124.0
# 4603569            Yes                157.0
# 6261642            Yes                 61.0
# 5480040             No                 26.0
# ...                ...                  ...
# 2176172            Yes                152.0
# 2451558            Yes                156.0
# 6576214             No                152.0
# 2515429             No                160.0
# 1071206            Yes                151.0
#
# [1000 rows x 7 columns]

# %%
# 결측치 파악
print(train_x.isnull().sum()) #결측 없음
print(valid_x.isnull().sum()) #결측 없음
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
# 연속형 변수만 선택
train_x.iloc[:10,[2,8,10]]
# Out:
#          Age  Annual_Premium  Vintage
# 2812995   45         23790.0      135
# 9653826   25         39662.0      191
# 3756146   22         28982.0      182
# 7295846   23         29567.0      228
# 8780476   65         51656.0      238
# 990191    65         48478.0      236
# 1022727   58         47979.0       97
# 1091953   21         27607.0      217
# 9341193   72          2630.0      228
# 8205635   33          2630.0      116

# %%
# IQR 기반 이상치 탐지 함수
def outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))
    return outliers

# 연속형 변수들에 대해 이상치 수 계산
print(outliers(train_x.iloc[:,[2,8,10]]).sum())
# Out:
# Age                  0
# Annual_Premium    2070
# Vintage              0
# dtype: int64

# %%
#연속형 변수들 시각화
fig, axes = plt.subplots(nrows=3, figsize=(15, 12))
axes = axes.flatten()

# 각 변수의 히스토그램 그리기
for ax, column in zip(axes, train_x.iloc[:,[2,8,10]]):
    ax.hist(train_x[column], bins=50, alpha=0.75)
    ax.set_title(f"Distribution of {column}")
    ax.set_xlabel(column)
    ax.set_ylabel("Frequency")


plt.tight_layout()
plt.show()

#Annual_Premium 변수의 min값이 정규분포에서 크게 튀어보이는 것을 확인할 수 있음

# %%
#튀어보이는 수치는 0이 아닌 2630.0
print(train_x["Annual_Premium"].min())
print(train_x["Annual_Premium"].min())

#이상치로 판단된 값 또한 대부분 2630.0
train_x.loc[outliers(train_x["Annual_Premium"]),"Annual_Premium"].value_counts()
# Out:
# 2630.0
# 2630.0
# Annual_Premium
# 2630.0     1839
# 70720.0       3
# 69856.0       2
# 61390.0       2
# 62738.0       2
#            ...
# 71483.0       1
# 68468.0       1
# 61795.0       1
# 75538.0       1
# 63332.0       1
# Name: count, Length: 222, dtype: int64

# %%
# 이분변수 생성: "Annual_Premium" == 2630.0 인 경우
train_x['Annual_Premium_Binary'] = (train_x['Annual_Premium'] == 2630.0).astype('category')
valid_x['Annual_Premium_Binary'] = (valid_x['Annual_Premium'] == 2630.0).astype('category')

# 로그 변환된 "Annual_Premium" 변수 생성
train_x['Annual_Premium_Log'] = np.log1p(train_x['Annual_Premium'])
valid_x['Annual_Premium_Log'] = np.log1p(valid_x['Annual_Premium'])

#생성된 변수 확인
train_x.head()
# Out:
#               id  Gender  Age  Driving_License  Region_Code  \
# 2812995  2812995    Male   45                1         30.0
# 9653826  9653826    Male   25                1          8.0
# 3756146  3756146  Female   22                1         35.0
# 7295846  7295846  Female   23                1         50.0
# 8780476  8780476    Male   65                1         28.0
#
#          Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 2812995                   1    1-2 Year             No         23790.0
# 9653826                   1    < 1 Year             No         39662.0
# 3756146                   0    < 1 Year            Yes         28982.0
# 7295846                   1    < 1 Year             No         29567.0
# 8780476                   0    1-2 Year            Yes         51656.0
#
#          Policy_Sales_Channel  Vintage Annual_Premium_Binary  \
# 2812995                 140.0      135                 False
# 9653826                 152.0      191                 False
# 3756146                 160.0      182                 False
# 7295846                 152.0      228                 False
# 8780476                  26.0      238                 False
#
#          Annual_Premium_Log
# 2812995           10.077063
# 9653826           10.588174
# 3756146           10.274465
# 7295846           10.294448
# 8780476           10.852381

# %%
# 정규화
# StandardScaler, MinMaxScaler, RobustScaler 중에서 선택
from sklearn.preprocessing import StandardScaler

# 최소-최대 정규화 (Min-Max 스케일링)
scaler = StandardScaler()
train_x.iloc[:,[2,8,10]] = scaler.fit_transform(train_x.iloc[:,[2,8,10]])
valid_x.iloc[:,[2,8,10]] = scaler.fit_transform(valid_x.iloc[:,[2,8,10]])

train_x.head()
# Out:
# /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/ipykernel_29914/2008341578.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.4457238  -0.88660458 -1.08645384 ... -1.08645384 -0.35367323
#   0.84542231]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_x.iloc[:,[2,8,10]] = scaler.fit_transform(train_x.iloc[:,[2,8,10]])
# /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/ipykernel_29914/2008341578.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.35637919  0.34438117  0.23175897 ...  1.02011438 -0.51905571
#  -1.4325469 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_x.iloc[:,[2,8,10]] = scaler.fit_transform(train_x.iloc[:,[2,8,10]])
# /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/ipykernel_29914/2008341578.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.03374552  0.11328626 -0.35902095  0.31570363  0.0458138  -0.62891078
#  -0.49396586  0.78801083  0.58559346  0.11328626 -0.96627306 -0.49396586
#   1.93504261  0.31570363 -0.02165866 -0.4264934   2.06998752 -0.96627306
#   0.31570363 -0.62891078  2.06998752 -1.16869044 -0.35902095  0.9904282
#  -0.02165866 -1.03374552  0.78801083  0.24823117 -0.22407603  1.26031803
#   1.93504261 -0.02165866  0.24823117 -0.49396586 -1.03374552  0.58559346
#   1.12537312 -1.03374552 -1.03374552  0.0458138   1.32779049 -1.16869044
#  -0.02165866  0.31570363  0.0458138  -0.62891078  1.4627354  -0.96627306
#  -0.02165866  1.93504261 -1.16869044 -0.76385569 -0.89880061  1.4627354
#   1.80009769  1.4627354   0.18075871  0.45064854  0.45064854 -1.23616289
#   0.92295575  1.05790066  2.13745998 -0.76385569 -1.03374552 -0.49396586
#  -0.15660357  1.73262523 -1.23616289 -0.89880061 -0.96627306  1.66515278
#   1.73262523 -0.96627306  0.58559346 -0.49396586 -0.96627306  0.9904282
#   0.72053837 -0.69638323  0.58559346  0.92295575  0.58559346  0.11328626
#   2.06998752 -0.96627306  0.31570363 -1.10121798 -0.02165866 -0.62891078
#  -0.96627306 -0.15660357 -0.89880061  0.72053837 -1.10121798  1.73262523
#  -0.02165866 -1.10121798  1.66515278  0.18075871  0.9904282   2.54229472
#  -0.08913112 -0.96627306 -0.69638323  2.00251506  0.31570363 -0.83132815
#  -0.89880061 -0.96627306  1.93504261  0.518121   -0.22407603 -1.16869044
#   1.4627354  -1.16869044  0.518121   -1.16869044  0.72053837  0.9904282
#   0.0458138  -0.08913112 -1.03374552 -0.22407603  1.39526295  0.31570363
#   0.11328626  1.19284558 -0.02165866 -1.16869044 -1.10121798 -0.83132815
#   0.31570363 -1.16869044 -0.96627306  0.58559346  0.38317609 -1.10121798
#   1.80009769 -0.29154849 -0.89880061 -0.76385569 -0.76385569  0.65306592
#  -1.10121798  0.31570363 -1.10121798  0.72053837 -1.03374552 -0.76385569
#  -1.16869044 -1.10121798 -1.10121798 -0.96627306  0.65306592 -1.16869044
#   0.18075871 -0.15660357  1.39526295  1.86757015  1.39526295  0.65306592
#   0.518121    0.45064854 -0.56143832 -0.96627306 -0.89880061 -0.83132815
#  -0.89880061 -0.83132815 -1.16869044  0.65306592  0.0458138  -1.03374552
#  -1.10121798  0.24823117 -0.89880061 -1.03374552 -1.10121798 -0.96627306
#  -0.89880061  0.518121   -0.76385569  0.85548329  0.45064854  0.38317609
#   0.45064854  0.18075871 -0.08913112  0.31570363 -0.02165866 -0.08913112
#   1.59768032 -0.96627306 -0.08913112  0.518121    1.80009769  0.58559346
#   2.06998752 -1.10121798 -0.15660357 -0.76385569 -0.96627306 -0.83132815
#  -1.03374552  2.40734981  0.45064854  0.18075871 -0.96627306  1.53020786
#   2.06998752  0.92295575  0.518121    0.11328626  0.518121    1.59768032
#  -0.89880061  0.78801083 -0.76385569 -1.03374552  2.00251506 -0.83132815
#   0.45064854 -1.16869044  0.65306592 -0.35902095  0.18075871  0.24823117
#   0.65306592  2.06998752  1.05790066 -0.35902095 -1.03374552 -0.49396586
#   1.93504261 -0.69638323  1.32779049 -0.83132815 -0.96627306  0.72053837
#   1.59768032 -1.10121798 -0.69638323  0.18075871  0.92295575 -1.16869044
#   1.19284558 -0.62891078 -0.89880061  0.85548329 -0.89880061 -0.96627306
#   0.72053837 -0.49396586 -0.83132815 -0.62891078  0.11328626 -0.35902095
#  -1.03374552 -0.89880061  0.31570363  1.80009769 -1.10121798 -1.10121798
#   0.38317609  0.0458138  -0.83132815  0.18075871  0.9904282   0.31570363
#  -0.83132815  2.00251506 -0.29154849 -1.16869044 -0.69638323  0.85548329
#   0.24823117 -0.15660357  0.18075871  0.45064854 -1.16869044 -0.62891078
#   0.9904282   0.0458138  -0.08913112  1.12537312 -1.16869044 -0.56143832
#  -0.83132815  0.78801083 -1.03374552 -0.96627306 -1.03374552 -0.89880061
#  -0.69638323 -1.10121798  0.58559346 -0.83132815 -0.76385569 -0.22407603
#  -1.03374552 -0.96627306 -1.16869044 -0.83132815  0.9904282   0.18075871
#   0.31570363  2.13745998 -0.83132815  1.32779049 -0.02165866  0.9904282
#   0.0458138  -1.16869044 -0.56143832  0.58559346 -1.10121798 -1.03374552
#  -1.03374552  2.33987735  0.24823117 -1.10121798  0.9904282   1.39526295
#   0.38317609 -1.16869044 -0.08913112  0.9904282  -1.03374552 -0.69638323
#  -0.02165866  2.47482227  1.19284558 -0.69638323 -1.10121798 -1.16869044
#   1.26031803 -0.89880061 -0.96627306  0.11328626  0.518121    0.45064854
#   1.26031803 -1.03374552  0.45064854 -0.89880061 -1.10121798 -0.89880061
#  -1.16869044 -0.29154849 -0.15660357  0.65306592 -0.22407603  1.26031803
#  -1.10121798 -1.03374552  0.92295575  0.0458138  -0.96627306 -1.10121798
#  -0.15660357 -0.96627306  0.92295575  2.27240489 -0.69638323 -1.16869044
#   0.45064854  1.05790066  0.518121    1.66515278  1.32779049  0.0458138
#  -0.96627306 -0.4264934  -1.23616289 -1.23616289 -1.03374552  0.31570363
#   1.86757015  1.32779049 -0.76385569 -1.10121798 -0.08913112 -1.10121798
#   1.80009769  0.38317609  0.11328626  0.9904282  -0.89880061 -0.76385569
#   0.45064854 -1.10121798  0.45064854 -0.96627306 -1.10121798  1.05790066
#  -1.23616289  0.518121   -0.89880061 -0.56143832 -1.03374552 -0.56143832
#  -1.10121798  0.45064854  2.7447121  -0.96627306  1.66515278  1.12537312
#  -0.83132815 -0.96627306  1.93504261  2.13745998 -1.03374552 -1.10121798
#  -0.69638323  1.19284558  1.66515278 -0.96627306  0.18075871 -0.76385569
#   1.59768032  0.0458138  -1.03374552 -0.96627306 -0.4264934   1.12537312
#  -1.10121798 -0.89880061 -1.10121798  0.38317609  0.58559346 -0.96627306
#  -1.03374552 -0.89880061  2.06998752 -0.76385569 -0.02165866 -1.10121798
#   0.45064854 -0.83132815 -1.16869044  0.92295575  0.45064854 -0.96627306
#   1.39526295  1.4627354   1.39526295 -0.35902095  0.518121   -1.16869044
#   1.39526295 -0.83132815  1.26031803 -1.23616289 -1.16869044 -0.76385569
#   1.53020786 -1.10121798  0.31570363 -0.89880061 -0.15660357  2.27240489
#   0.85548329  0.85548329  0.92295575  1.26031803 -1.03374552 -0.35902095
#  -0.22407603 -1.10121798  0.9904282  -1.03374552  1.53020786  0.72053837
#  -0.08913112  0.72053837 -1.16869044 -0.96627306 -1.23616289 -0.76385569
#  -0.02165866  0.31570363  0.85548329 -0.96627306  1.4627354  -1.03374552
#   2.00251506 -1.16869044  1.19284558  0.92295575 -0.89880061  1.32779049
#   1.26031803 -0.56143832  1.26031803  1.19284558 -0.89880061  0.72053837
#   0.58559346 -0.62891078  0.45064854 -0.83132815 -0.15660357 -0.96627306
#   0.45064854  0.11328626 -1.16869044  1.53020786  1.73262523  0.85548329
#   0.31570363 -1.03374552 -0.96627306  0.72053837 -0.76385569 -0.56143832
#  -0.89880061 -1.03374552 -0.96627306  0.65306592 -1.10121798 -0.35902095
#  -0.96627306  1.66515278 -0.89880061  0.18075871 -0.83132815  0.78801083
#  -0.49396586 -1.03374552  0.31570363 -1.10121798 -1.10121798 -0.89880061
#  -0.76385569 -1.03374552 -1.10121798  0.31570363  0.31570363 -0.62891078
#  -1.10121798  0.38317609 -1.03374552  0.518121    0.85548329 -0.22407603
#  -1.10121798 -0.89880061 -0.96627306  1.32779049  0.31570363  0.24823117
#  -0.56143832 -1.03374552  1.19284558  0.38317609  0.92295575 -1.16869044
#   1.12537312  1.12537312  1.39526295 -1.16869044  2.06998752  0.72053837
#  -1.10121798  0.518121    1.19284558 -0.02165866  0.85548329  0.45064854
#  -0.56143832 -0.96627306  1.4627354   0.518121   -0.56143832 -1.16869044
#   0.24823117 -0.35902095  0.9904282  -1.10121798  1.4627354  -1.10121798
#  -0.89880061  2.40734981  0.45064854  0.18075871 -1.03374552  0.0458138
#   1.05790066 -0.89880061  0.85548329  1.19284558  0.72053837 -0.62891078
#   0.85548329 -1.03374552 -0.62891078 -1.10121798 -1.03374552  0.38317609
#   0.92295575 -0.83132815 -0.35902095  0.92295575 -0.29154849 -1.10121798
#   0.24823117  0.92295575  1.05790066 -0.08913112  0.31570363 -1.03374552
#  -0.89880061  0.92295575 -0.96627306  1.80009769 -0.83132815  2.00251506
#  -0.02165866 -1.03374552  0.18075871  0.9904282   1.86757015  1.32779049
#  -0.15660357 -0.96627306 -0.69638323 -1.16869044  1.66515278 -0.96627306
#   0.65306592  0.24823117  0.85548329 -0.96627306 -0.35902095 -0.83132815
#  -1.10121798 -0.96627306 -0.83132815 -0.83132815 -1.16869044 -1.10121798
#   0.11328626  0.518121    0.11328626 -1.23616289  0.11328626  1.59768032
#   0.518121    0.38317609  1.32779049 -0.15660357  2.00251506 -0.62891078
#  -1.03374552 -0.96627306  0.78801083 -0.96627306  0.9904282   0.518121
#   0.72053837  2.00251506  0.85548329  0.0458138   1.4627354  -0.96627306
#   1.12537312  1.93504261 -1.03374552  1.05790066 -1.10121798  0.92295575
#  -1.10121798  0.38317609 -1.03374552 -0.96627306 -0.76385569 -0.35902095
#   0.0458138   0.58559346 -0.96627306 -0.89880061  0.45064854 -0.96627306
#  -0.08913112  0.31570363 -0.76385569 -0.89880061 -0.83132815  2.20493244
#   0.11328626 -1.16869044  0.38317609  0.18075871  0.0458138   0.11328626
#   0.31570363 -1.10121798 -0.62891078  0.92295575 -0.56143832 -1.10121798
#   1.32779049  0.518121   -0.49396586 -0.62891078  2.20493244 -1.03374552
#   1.19284558  2.00251506  0.31570363 -0.69638323 -1.10121798  0.72053837
#   0.9904282   0.31570363 -1.10121798 -1.10121798 -0.29154849  2.00251506
#  -1.16869044 -0.96627306 -1.10121798 -0.69638323  0.92295575  1.4627354
#  -0.96627306 -0.35902095  1.73262523 -0.22407603  0.24823117 -0.29154849
#  -0.62891078 -0.69638323 -0.35902095  0.518121   -0.62891078 -0.56143832
#   0.38317609  0.65306592 -0.02165866 -0.96627306  0.38317609 -0.29154849
#  -0.83132815  0.78801083  0.18075871 -0.49396586  0.38317609 -1.16869044
#   2.06998752 -1.03374552  2.40734981  1.59768032  0.11328626 -0.29154849
#   0.45064854  1.05790066 -0.96627306 -1.03374552 -0.62891078 -1.16869044
#  -1.10121798  2.27240489  0.38317609 -0.69638323  0.518121   -0.89880061
#   0.85548329  1.39526295 -0.89880061  0.31570363 -0.89880061 -0.89880061
#   0.92295575 -0.35902095  0.85548329  2.00251506  1.19284558  0.38317609
#  -0.62891078  2.54229472  1.39526295 -0.83132815 -0.96627306 -0.22407603
#   0.38317609  0.85548329 -0.62891078 -1.03374552  0.45064854  0.85548329
#  -1.10121798 -0.89880061 -1.10121798  1.73262523 -0.89880061  0.24823117
#  -0.62891078 -0.96627306 -0.08913112  1.19284558  0.78801083  0.18075871
#   0.18075871 -1.03374552 -0.96627306  1.93504261  1.66515278 -1.23616289
#  -0.89880061  2.67723964 -1.16869044  1.53020786 -0.76385569  1.12537312
#  -0.83132815 -0.4264934  -1.03374552 -1.10121798  0.58559346  2.27240489
#   1.93504261 -0.15660357 -1.10121798 -0.96627306  1.73262523  1.4627354
#  -1.10121798  1.59768032 -0.83132815  0.58559346 -0.76385569 -0.22407603
#  -0.89880061  0.31570363 -1.10121798 -0.89880061 -0.02165866 -1.23616289
#  -0.02165866  0.18075871  1.12537312 -0.96627306 -0.08913112 -0.89880061
#  -1.03374552 -0.96627306  0.24823117 -1.10121798 -1.03374552  0.45064854
#  -1.03374552 -0.76385569 -0.08913112  0.18075871  0.58559346  1.80009769
#   0.58559346  0.58559346 -1.16869044  0.31570363 -0.08913112 -1.10121798
#   2.33987735 -0.96627306 -0.76385569  0.65306592  0.45064854 -1.16869044
#  -1.10121798  0.11328626  0.18075871 -0.08913112  0.72053837 -0.89880061
#  -1.16869044 -1.03374552 -0.22407603  0.38317609  1.12537312 -0.89880061
#   1.66515278 -0.96627306  1.05790066  0.31570363  0.24823117 -0.96627306
#  -0.83132815 -1.10121798  1.05790066  0.92295575 -0.83132815 -0.22407603
#   0.78801083  0.65306592  2.54229472 -0.76385569 -0.83132815  0.24823117
#   0.45064854 -1.16869044  0.78801083 -0.96627306  2.00251506  0.518121
#  -0.62891078  0.65306592  0.31570363  0.78801083 -1.16869044 -0.49396586
#  -1.16869044  2.40734981  1.93504261  0.9904282   0.92295575  1.26031803
#  -0.96627306 -0.56143832 -1.03374552 -0.76385569 -1.10121798 -0.49396586
#   0.65306592  1.05790066 -1.03374552 -0.4264934   0.78801083 -0.4264934
#  -0.22407603  0.92295575  1.39526295 -0.56143832 -0.96627306  0.85548329
#  -0.02165866 -1.03374552 -0.96627306  0.24823117 -0.56143832  2.06998752
#  -1.03374552  0.92295575  0.518121   -0.69638323  1.73262523  0.11328626
#  -1.10121798  0.65306592  0.18075871  1.32779049  1.26031803  0.0458138
#  -0.89880061 -1.03374552 -0.15660357 -0.89880061 -0.89880061 -0.69638323
#  -0.15660357  0.31570363  1.4627354  -0.69638323  0.24823117  1.53020786
#  -1.03374552  2.00251506 -0.76385569 -0.69638323 -0.89880061  1.73262523
#  -1.10121798 -0.02165866 -0.83132815 -1.03374552 -0.76385569  0.518121
#   1.66515278 -0.22407603  1.05790066 -0.89880061 -0.89880061 -0.08913112
#   0.85548329  1.59768032 -0.96627306 -1.03374552  1.32779049 -0.76385569
#  -1.10121798 -1.16869044 -0.83132815 -1.16869044 -0.62891078 -0.69638323
#  -0.35902095 -0.89880061 -0.96627306 -0.96627306]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   valid_x.iloc[:,[2,8,10]] = scaler.fit_transform(valid_x.iloc[:,[2,8,10]])
# /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/ipykernel_29914/2008341578.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.57340654 -0.86457565 -0.76506618 -1.42431646 -1.71040621 -0.37946695
#  -0.51629248 -1.84723174 -0.57848591  1.57340654  1.16292994 -0.65311801
#  -0.67799538 -1.77259963  0.81464677 -1.51138725  0.92659493  1.46145837
#  -0.30483484  1.53609048  0.26734465 -1.92186385  1.28731679  1.16292994
#  -0.20532537 -1.17554277  0.7151373  -1.6357741  -0.67799538  1.46145837
#   1.66047733  0.7151373  -1.06359461 -0.49141511  1.0385431  -1.58601936
#   1.44901969  0.01857096 -0.21776405  1.62316127  0.75245335 -1.10091066
#  -0.08093852 -1.32480698 -0.20532537  1.00122704  0.40417018 -1.11334935
#   1.0385431   1.31219416  0.10564175 -0.87701434 -0.32971221 -0.75262749
#  -0.77750486 -0.64067933  0.57831176 -0.76506618  0.74001466 -1.13822671
#  -0.67799538 -0.05606115 -1.00140118 -1.05115592  1.5236518   0.72757598
#   0.83952414  0.7151373  -1.32480698 -0.24264142 -0.61580196 -1.3123683
#   0.16783517 -1.62333542  0.36685413  1.21268468 -0.13069326  0.70269861
#  -1.57358068  0.25490596 -0.71531144 -0.29239616  1.1131752   0.10564175
#   0.3917315  -1.44919383  1.37438758  0.35441544  0.36685413  0.69025993
#   1.07585915 -0.21776405 -0.90189171 -0.05606115  0.01857096 -1.57358068
#   1.2748781   1.46145837  0.6280665  -1.25017488  1.47389706  1.47389706
#   0.83952414  0.25490596 -0.23020274  1.21268468  1.64803864  0.18027386
#  -0.45409906 -1.17554277  0.61562782  0.1429578  -1.00140118  1.05098178
#  -0.76506618 -0.39190564  0.26734465 -0.57848591 -1.46163252  0.36685413
#  -1.29992962  0.74001466  0.77733072  1.62316127 -1.26261356 -1.23773619
#  -1.10091066 -1.13822671  0.10564175 -0.92676908 -0.00630641  1.02610441
#   1.58584522  0.70269861 -0.35458958 -0.08093852 -0.86457565  1.47389706
#   0.31709939 -1.18798145  1.64803864  1.21268468  0.64050519 -1.77259963
#   0.40417018  0.27978333  0.83952414  0.34197676 -0.59092459  0.36685413
#   0.04344833  1.56096785 -1.07603329  0.32953807  1.53609048 -0.72775012
#  -0.56604722 -0.26751879  1.46145837 -0.31727353  1.54852917 -0.27995748
#   1.46145837  0.4663636  -1.20042014 -0.91433039 -1.66065147  1.15049126
#  -0.180448    0.77733072  1.1131752  -0.05606115 -1.18798145 -0.56604722
#  -0.52873117 -0.69043407  0.42904755 -1.05115592 -1.10091066  1.33707153
#   0.6280665   0.76489203 -1.68552884 -1.36212304 -1.87210911 -0.97652381
#  -0.15557063  0.96391099  0.35441544  0.85196283 -1.08847198 -1.01383987
#   1.66047733 -0.08093852 -1.83479305  1.02610441 -1.4740712  -0.04362247
#  -0.00630641  0.6280665  -0.08093852 -0.25508011 -0.86457565 -0.09337721
#  -1.72284489 -1.90942516  1.47389706 -1.48650988 -0.3421509   1.5982839
#   0.24246728 -1.13822671  1.66047733  1.26243942 -1.4740712  -0.52873117
#   0.70269861  1.38682627  0.83952414  1.22512337 -1.69796752  0.40417018
#  -0.64067933  1.38682627  0.7897694   0.91415625 -1.06359461 -1.88454779
#  -1.36212304  0.96391099  0.00613227  1.0385431   0.36685413  0.65294387
#  -0.40434432 -0.86457565  0.26734465 -1.58601936  0.09320306 -1.37456172
#   1.23756205  0.32953807  0.54099571 -1.90942516  0.5534344   1.21268468
#  -0.80238223 -0.0187451   0.37929281  0.98878836  0.00613227  0.50367966
#  -0.71531144  0.6280665   0.76489203  0.27978333 -0.72775012  1.06342047
#  -0.00630641  0.24246728 -0.11825457  1.31219416 -0.61580196 -0.72775012
#   0.52855703  1.07585915  0.35441544  0.32953807 -0.08093852 -0.44166038
#   0.1429578   0.6280665  -0.37946695  0.57831176 -0.42922169  0.70269861
#  -1.49894857 -0.05606115 -0.90189171 -1.25017488  1.21268468  0.05588701
#  -1.00140118  0.70269861  0.98878836 -0.44166038 -1.87210911  0.01857096
#   1.28731679  0.1429578  -0.47897643 -1.54870331 -1.57358068  0.67782124
#  -1.44919383 -0.51629248 -0.41678301 -1.01383987 -1.67309015  1.01366573
#   1.47389706 -0.41678301  0.36685413  0.6280665  -1.46163252  1.0385431
#   0.3046607   0.60318913 -0.45409906  1.13805257 -1.13822671  0.83952414
#  -0.97652381 -0.31727353 -0.23020274 -0.11825457 -1.66065147  0.4663636
#   1.46145837  1.01366573  0.61562782  1.21268468 -0.03118378 -0.03118378
#   1.26243942  0.19271254  0.83952414  0.77733072 -1.32480698 -1.20042014
#   0.20515123  1.46145837  1.61072259  1.2748781   0.7897694  -0.55360854
#  -0.61580196 -0.25508011  0.27978333  1.00122704  0.3917315   0.41660886
#  -1.26261356  0.93903362 -0.86457565 -0.77750486  0.10564175  1.02610441
#   1.5982839   0.81464677 -0.08093852  1.200246    0.9514723   1.62316127
#   1.49877443 -1.74772226 -0.40434432  0.76489203  0.9514723   0.6280665
#  -0.9889625  -1.23773619 -1.01383987 -0.69043407  0.11808043  1.48633574
#  -0.49141511 -0.30483484  0.03100964 -0.29239616 -1.06359461 -1.18798145
#  -1.52382594 -1.00140118  0.23002859  1.28731679 -1.42431646  1.05098178
#  -0.41678301 -1.20042014  0.37929281 -1.43675515  1.22512337 -1.88454779
#  -1.62333542 -0.85213697  1.5982839   1.0385431  -0.87701434 -0.85213697
#   1.0385431   1.26243942 -0.180448    1.22512337  0.00613227 -0.80238223
#   1.58584522  1.57340654  0.90171757 -1.05115592 -0.31727353 -0.13069326
#   0.36685413  0.10564175  1.2748781   0.96391099  1.33707153  1.25000073
#  -1.62333542  0.80220809  1.44901969  0.16783517 -1.74772226 -0.8272596
#  -0.85213697  1.44901969  0.01857096 -1.78503832  1.01366573  0.00613227
#   0.98878836  1.00122704  0.75245335 -1.54870331 -0.56604722  0.64050519
#   1.58584522  1.13805257  1.25000073  1.64803864 -0.97652381 -0.0187451
#   0.6280665   0.35441544  1.0385431   1.13805257 -1.03871724 -0.85213697
#   0.76489203  0.18027386 -0.69043407  1.53609048 -0.51629248 -0.41678301
#  -1.06359461  0.21758991 -1.06359461  1.07585915 -1.48650988 -1.71040621
#   1.26243942 -1.26261356 -1.87210911 -1.13822671  0.37929281  0.10564175
#   0.42904755 -0.56604722  1.0385431   1.22512337  0.35441544 -0.25508011
#  -1.71040621 -0.36702827  1.31219416  1.28731679 -1.37456172  1.22512337
#   1.46145837 -0.32971221 -1.49894857  1.06342047 -0.92676908  0.7151373
#  -0.64067933  1.33707153  1.2748781   0.04344833 -0.67799538 -0.76506618
#   1.44901969 -0.06849984  0.56587308  0.35441544 -1.58601936 -1.43675515
#  -1.12578803  1.66047733 -0.69043407  1.48633574 -0.69043407  1.5236518
#   0.34197676 -0.85213697 -0.09337721 -1.66065147 -1.6357741   0.97634967
#  -0.11825457  0.08076438  0.93903362 -1.67309015  1.22512337 -0.93920776
#   1.01366573  0.06832569  0.25490596  0.03100964 -0.76506618 -0.35458958
#  -0.69043407  0.3046607   1.48633574 -0.51629248 -1.01383987  1.37438758
#  -0.85213697  0.75245335 -0.74018881  1.08829783 -0.90189171  1.29975547
#   1.5236518  -0.46653774 -0.80238223  0.27978333  0.50367966  0.37929281
#  -0.41678301  0.1429578   1.64803864 -0.45409906  0.64050519 -0.90189171
#   0.15539649  0.15539649  0.32953807 -1.08847198  0.3046607   0.57831176
#   0.93903362 -0.61580196  0.4663636  -0.92676908 -0.21776405 -0.96408513
#  -1.43675515 -1.67309015  0.6280665  -1.16310408 -1.84723174  1.25000073
#   1.33707153 -1.52382594 -0.80238223 -1.89698648 -1.66065147 -1.71040621
#  -0.10581589  0.66538256 -0.6655567  -1.07603329 -0.69043407 -1.07603329
#  -1.53626462  0.72757598 -0.08093852 -1.69796752  0.83952414 -1.83479305
#  -0.47897643 -0.78994355 -0.32971221  1.07585915 -1.66065147  1.66047733
#  -0.35458958 -0.96408513  0.85196283 -1.46163252 -0.74018881 -0.91433039
#  -0.76506618  1.22512337 -1.6357741  -1.54870331  1.15049126  1.15049126
#   0.96391099  0.77733072  0.06832569  0.36685413  1.32463284  0.74001466
#   1.63559996  1.21268468  1.16292994  1.436581   -0.47897643 -0.83969828
#  -0.62824064 -0.08093852  0.85196283 -0.97652381  0.56587308 -0.36702827
#  -1.18798145  0.40417018 -0.05606115  1.12561389 -0.77750486 -0.95164645
#  -0.21776405  0.67782124 -1.43675515 -1.01383987  0.60318913 -1.07603329
#   0.5534344   1.46145837  1.57340654  1.47389706 -0.27995748 -0.46653774
#   1.22512337  0.64050519 -1.49894857 -1.16310408 -0.49141511 -0.96408513
#  -0.71531144  0.00613227 -0.62824064 -0.21776405 -0.90189171  0.8768402
#  -1.17554277 -0.74018881  0.75245335 -1.18798145  1.05098178  0.3046607
#   0.69025993 -1.44919383  1.2748781   1.07585915  0.54099571  0.98878836
#   1.08829783  1.06342047 -1.71040621 -0.35458958 -1.12578803 -0.95164645
#  -0.76506618  0.16783517 -0.72775012 -0.27995748  1.2748781   1.33707153
#   0.69025993  0.98878836 -1.12578803 -0.16800931  0.16783517  1.05098178
#  -1.38700041 -0.81482091  1.58584522 -0.78994355 -0.9889625   0.26734465
#   0.3046607  -1.18798145  1.07585915  0.26734465 -0.51629248  1.54852917
#   0.76489203  0.51611834  0.27978333 -0.72775012 -1.52382594  0.83952414
#  -0.81482091 -1.10091066 -0.06849984 -0.69043407 -1.01383987  1.08829783
#  -1.78503832  0.96391099  0.42904755  1.66047733 -0.88945302 -0.80238223
#   0.37929281  0.09320306 -1.67309015  1.13805257 -1.71040621  0.05588701
#  -0.71531144  0.91415625 -0.19288668 -0.96408513  0.05588701  1.31219416
#   0.76489203  1.5982839   1.58584522  1.1131752   1.37438758  1.49877443
#   0.97634967  0.35441544  1.66047733  1.33707153 -0.30483484  0.91415625
#   1.57340654  1.28731679 -1.53626462 -1.16310408 -0.08093852  1.05098178
#  -1.26261356 -0.76506618  0.90171757 -0.75262749  0.80220809 -0.60336328
#   0.06832569 -1.29992962  1.32463284  0.59075045 -1.57358068  0.04344833
#  -1.67309015 -0.69043407 -0.19288668  0.93903362 -0.23020274 -0.65311801
#  -1.06359461 -0.61580196  1.436581    0.21758991  0.29222202 -1.01383987
#  -1.13822671  1.00122704 -1.68552884  1.0385431   1.2748781  -1.17554277
#  -1.10091066 -0.19288668 -1.54870331  0.98878836 -0.45409906  1.06342047
#   1.21268468 -1.06359461  0.36685413 -0.8272596   0.35441544  1.58584522
#  -0.20532537 -0.87701434  0.6280665   0.11808043 -1.74772226 -0.90189171
#   0.05588701 -1.06359461 -0.42922169 -1.20042014 -1.18798145  0.13051912
#  -1.43675515 -0.14313194  0.57831176  1.5236518  -0.27995748  0.09320306
#   0.27978333 -0.87701434 -0.83969828 -0.78994355  1.18780731 -0.86457565
#   0.70269861 -1.26261356 -0.15557063  1.41170364  0.3917315   1.57340654
#   1.67291601  0.11808043  0.66538256  0.64050519 -1.71040621  1.32463284
#  -0.51629248  0.15539649 -0.21776405  1.22512337 -1.87210911  0.18027386
#   1.31219416 -1.92186385 -1.05115592 -0.92676908 -0.8272596   0.00613227
#   1.10073652  1.39926495 -0.97652381 -0.23020274 -1.33724567  1.53609048
#  -1.66065147 -1.02627855  0.9514723  -0.87701434 -0.6655567   0.70269861
#  -1.74772226  0.52855703 -0.67799538 -0.37946695  0.15539649 -1.49894857
#   1.34951021 -1.74772226 -0.74018881  0.75245335  1.32463284 -0.5038538
#   0.7151373  -0.96408513  0.74001466  0.25490596  0.42904755  0.27978333
#  -1.73528358 -0.81482091 -0.14313194  0.13051912 -0.95164645  0.00613227
#   1.1131752   0.3917315   0.72757598  1.18780731  0.37929281  1.1131752
#   0.09320306 -1.62333542 -0.41678301  0.40417018 -1.29992962 -0.65311801
#  -0.62824064  1.18780731 -1.76016095 -1.58601936 -1.10091066  0.90171757
#  -1.01383987 -1.74772226 -0.00630641  0.66538256 -0.11825457 -0.41678301
#  -1.43675515 -0.6655567  -1.27505225 -1.23773619  0.06832569 -0.92676908
#   0.70269861  1.63559996  1.46145837 -0.77750486  1.00122704 -0.03118378
#   1.34951021  0.40417018 -1.18798145  0.09320306 -1.06359461  0.67782124
#   1.200246   -0.15557063  0.4663636  -0.87701434  1.06342047  0.56587308
#   0.57831176  0.93903362  0.5534344   0.19271254  1.58584522 -0.55360854
#   1.56096785  1.34951021  0.9514723   0.54099571  1.53609048  0.80220809
#   1.41170364 -0.16800931 -1.74772226  1.67291601  0.06832569 -0.69043407
#   1.26243942  0.75245335  1.31219416 -0.8272596  -0.6655567  -0.57848591
#  -0.08093852  1.12561389  0.8768402   1.56096785  0.49124097  0.57831176
#  -0.91433039 -1.08847198  0.05588701  0.23002859  1.17536863  0.50367966
#   1.37438758  0.23002859 -0.37946695 -1.26261356  0.96391099  0.27978333
#  -1.80991569  1.00122704  0.16783517 -0.15557063  1.28731679 -0.03118378
#  -0.29239616  1.06342047 -0.09337721  1.22512337 -0.62824064 -0.08093852
#  -0.11825457 -0.05606115 -0.70287275  1.51121311 -0.06849984 -0.81482091
#   0.19271254 -1.18798145  0.13051912  1.5982839   0.74001466 -0.71531144
#   1.13805257 -1.12578803 -0.41678301 -1.57358068  1.10073652  1.66047733
#   0.60318913 -0.31727353  0.72757598 -0.14313194  1.07585915 -0.60336328
#  -0.74018881  0.90171757 -0.95164645 -1.67309015 -0.67799538  0.20515123
#  -0.54116985  0.32953807 -0.15557063 -1.58601936  0.52855703 -1.71040621
#   0.50367966  0.36685413 -0.90189171 -0.39190564  0.4663636  -1.00140118
#  -0.62824064  0.31709939  1.31219416  1.01366573]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   valid_x.iloc[:,[2,8,10]] = scaler.fit_transform(valid_x.iloc[:,[2,8,10]])
#               id  Gender       Age  Driving_License  Region_Code  \
# 2812995  2812995    Male  0.445724                1         30.0
# 9653826  9653826    Male -0.886605                1          8.0
# 3756146  3756146  Female -1.086454                1         35.0
# 7295846  7295846  Female -1.019837                1         50.0
# 8780476  8780476    Male  1.778052                1         28.0
#
#          Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 2812995                   1    1-2 Year             No       -0.403585
# 9653826                   1    < 1 Year             No        0.566838
# 3756146                   0    < 1 Year            Yes       -0.086143
# 7295846                   1    < 1 Year             No       -0.050376
# 8780476                   0    1-2 Year            Yes        1.300158
#
#          Policy_Sales_Channel   Vintage Annual_Premium_Binary  \
# 2812995                 140.0 -0.356379                 False
# 9653826                 152.0  0.344381                 False
# 3756146                 160.0  0.231759                 False
# 7295846                 152.0  0.807384                 False
# 8780476                  26.0  0.932519                 False
#
#          Annual_Premium_Log
# 2812995           10.077063
# 9653826           10.588174
# 3756146           10.274465
# 7295846           10.294448
# 8780476           10.852381

# %%
# 예측에 필요 없는 'id'와 'Annual_Premium' 변수를 드롭
train_x = train_x.drop(columns=['id', 'Annual_Premium'])
valid_x = valid_x.drop(columns=['id', 'Annual_Premium'])

# 원-핫 인코딩 (One-Hot Encoding)
train_x = pd.get_dummies(train_x, columns=['Gender', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel', 'Annual_Premium_Binary'])
valid_x = pd.get_dummies(valid_x, columns=['Gender', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Policy_Sales_Channel', 'Annual_Premium_Binary'])

# train_x와 valid_x가 동일한 열을 가지도록 조정
train_x, valid_x = train_x.align(valid_x, join='left', axis=1, fill_value=0)

#생성된 변수 확인
train_x.head()
# Out:
#               Age   Vintage  Annual_Premium_Log  Gender_Female  Gender_Male  \
# 2812995  0.445724 -0.356379           10.077063          False         True
# 9653826 -0.886605  0.344381           10.588174          False         True
# 3756146 -1.086454  0.231759           10.274465           True        False
# 7295846 -1.019837  0.807384           10.294448           True        False
# 8780476  1.778052  0.932519           10.852381          False         True
#
#          Driving_License_0  Driving_License_1  Region_Code_0.0  \
# 2812995              False               True            False
# 9653826              False               True            False
# 3756146              False               True            False
# 7295846              False               True            False
# 8780476              False               True            False
#
#          Region_Code_1.0  Region_Code_2.0  ...  Policy_Sales_Channel_153.0  \
# 2812995            False            False  ...                       False
# 9653826            False            False  ...                       False
# 3756146            False            False  ...                       False
# 7295846            False            False  ...                       False
# 8780476            False            False  ...                       False
#
#          Policy_Sales_Channel_154.0  Policy_Sales_Channel_155.0  \
# 2812995                       False                       False
# 9653826                       False                       False
# 3756146                       False                       False
# 7295846                       False                       False
# 8780476                       False                       False
#
#          Policy_Sales_Channel_156.0  Policy_Sales_Channel_157.0  \
# 2812995                       False                       False
# 9653826                       False                       False
# 3756146                       False                       False
# 7295846                       False                       False
# 8780476                       False                       False
#
#          Policy_Sales_Channel_158.0  Policy_Sales_Channel_160.0  \
# 2812995                       False                       False
# 9653826                       False                       False
# 3756146                       False                        True
# 7295846                       False                       False
# 8780476                       False                       False
#
#          Policy_Sales_Channel_163.0  Annual_Premium_Binary_False  \
# 2812995                       False                         True
# 9653826                       False                         True
# 3756146                       False                         True
# 7295846                       False                         True
# 8780476                       False                         True
#
#          Annual_Premium_Binary_True
# 2812995                       False
# 9653826                       False
# 3756146                       False
# 7295846                       False
# 8780476                       False
#
# [5 rows x 152 columns]

# %% [markdown]
# ------------------------------------------------ 이제 드디어 모델링 ------------------------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import time

# 시작 시간 기록
start_time = time.time()

# 로지스틱 회귀 모델 생성 및 학습
logistic_model = LogisticRegression(max_iter=1000, random_state=42)
logistic_model.fit(train_x, train_y)

# 검증 데이터에 대해 예측
valid_y_pred = logistic_model.predict(valid_x)

# 성능 평가
accuracy = accuracy_score(valid_y, valid_y_pred)
conf_matrix = confusion_matrix(valid_y, valid_y_pred)
class_report = classification_report(valid_y, valid_y_pred)

# 종료 시간 기록
end_time = time.time()
execution_time = end_time - start_time

# 결과 출력
print(accuracy)
print(conf_matrix)
print(class_report)
print("실행 시간: %f초" %execution_time)
# Out:
# 0.878
# [[878   3]
#  [119   0]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       881
#            1       0.00      0.00      0.00       119
#
#     accuracy                           0.88      1000
#    macro avg       0.44      0.50      0.47      1000
# weighted avg       0.78      0.88      0.82      1000
#
# 실행 시간: 1.160418초

# %% [markdown]
# 가장 단순한 로지스틱 회귀 결과 0.878의 정확도를 얻었다. 그러나 119개 참값 중 불과 0개를 맞춰 형편 없는 재현율(Recall)을 보이고 있다.
