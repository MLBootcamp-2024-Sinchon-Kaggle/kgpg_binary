# %%
import h2o
from h2o.automl import H2OAutoML
from sklearn.datasets import load_iris
import pandas as pd

# H2O 초기화
h2o.init()

# 데이터 로드 및 H2O 프레임으로 변환
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
h2o_df = h2o.H2OFrame(df)

# 데이터 분할
train, test = h2o_df.split_frame(ratios=[.8], seed=42)

# AutoML 모델 생성 및 학습
aml = H2OAutoML(max_runtime_secs=120, seed=42)
aml.train(y='target', training_frame=train)

# 모델 평가
lb = aml.leaderboard
print(lb.head())

# 최적의 모델 정보 출력
best_model = aml.leader
print(best_model)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321.
# .... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_421"; Java(TM) SE Runtime Environment (build 1.8.0_421-b09); Java HotSpot(TM) 64-Bit Server VM (build 25.421-b09, mixed mode)
#   Starting server from /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/tmpfy8kk7s3
#   JVM stdout: /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/tmpfy8kk7s3/h2o_jaesolshin_started_from_python.out
#   JVM stderr: /var/folders/fx/7qldcfl92nb_g9hqp_lrssxm0000gn/T/tmpfy8kk7s3/h2o_jaesolshin_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ---------------------------------
# H2O_cluster_uptime:         15 secs
# H2O_cluster_timezone:       Asia/Seoul
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.4
# H2O_cluster_version_age:    10 days
# H2O_cluster_name:           H2O_from_python_jaesolshin_zvfdh3
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.770 Gb
# H2O_cluster_total_cores:    0
# H2O_cluster_allowed_cores:  0
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.0 final
# --------------------------  ---------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |█
# 15:43:47.213: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 75.0.
#
# ██████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                  rmse          mse          mae        rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_1_20240720_154344_model_96       1.33848e-06  1.79153e-12  9.53749e-07  6.19698e-07               1.79153e-12
# GBM_grid_1_AutoML_1_20240720_154344_model_1        0.0479157    0.00229591   0.0279366    0.0230786                 0.00229591
# XGBoost_grid_1_AutoML_1_20240720_154344_model_371  0.0571058    0.00326107   0.0412869    0.0244414                 0.00326107
# XGBoost_grid_1_AutoML_1_20240720_154344_model_121  0.0571789    0.00326943   0.0383692    0.022942                  0.00326943
# XGBoost_grid_1_AutoML_1_20240720_154344_model_205  0.0574851    0.00330454   0.0332913    0.0257408                 0.00330454
# XGBoost_grid_1_AutoML_1_20240720_154344_model_455  0.0575004    0.00330629   0.0364775    0.0242016                 0.00330629
# XGBoost_grid_1_AutoML_1_20240720_154344_model_312  0.0581258    0.00337861   0.0346436    0.0234272                 0.00337861
# XGBoost_grid_1_AutoML_1_20240720_154344_model_110  0.0607114    0.00368588   0.0431146    0.0247211                 0.00368588
# XGBoost_grid_1_AutoML_1_20240720_154344_model_206  0.063343     0.00401234   0.0456433    0.029066                  0.00401234
# XGBoost_grid_1_AutoML_1_20240720_154344_model_456  0.0653374    0.00426897   0.043596     0.035947                  0.00426897
# [10 rows x 6 columns]
#
# Model Details
# =============
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_grid_1_AutoML_1_20240720_154344_model_96
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     160                160                         23416                  3            5            3.9           6             10            6.95
#
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 1.5546445426474654e-13
# RMSE: 3.942898099935459e-07
# MAE: 3.407451333714562e-07
# RMSLE: 1.6392683332126473e-07
# Mean Residual Deviance: 1.5546445426474654e-13
#
# ModelMetricsRegression: gbm
# ** Reported on validation data. **
#
# MSE: 1.7915250387870008e-12
# RMSE: 1.3384786284386468e-06
# MAE: 9.537486240773774e-07
# RMSLE: 6.196980825190459e-07
# Mean Residual Deviance: 1.7915250387870008e-12
#
# Scoring History:
#      timestamp            duration    number_of_trees    training_rmse           training_mae            training_deviance       validation_rmse         validation_mae          validation_deviance
# ---  -------------------  ----------  -----------------  ----------------------  ----------------------  ----------------------  ----------------------  ----------------